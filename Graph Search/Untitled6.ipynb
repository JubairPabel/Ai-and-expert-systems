# %%
graph = {
    "Arad": {"Timisoara": 118, "Sibiu": 140,"Zerind": 75},
    "Zerind": {"Arad": 75, "Oradea": 71},
    "Oradea": {"Zerind": 71, "Sibiu": 151},
    "Timisoara": {"Arad": 118, "Lugoj": 111},
    "Lugoj": {"Timisoara": 111, "Mehadia":70},
    "Mehadia": {"Lugoj": 70, "Dobreta": 75},
    "Dobreta": {"Mehadia":75, "Craiova":120},
    "Craiova": {"Dobreta": 120, "RimnicuVilcea": 146, "Pitesi": 138},
    "RimnicuVilcea": {"Craiova": 146, "Pitesi": 97, "Sibiu":80},
    "Sibiu": {"Arad": 140, "Oradea":151, "RimnicuVilcea": 80, "Fagaras": 99},
    "Fagaras": {"Sibiu": 99, "Bucharest":211},
    "Pitesi": {"Bucharest": 101, "RimnicuVilcea": 97, "Craiova": 138},
    "Bucharest": {"Pitesi": 101, "Fagaras": 211, "Giurgiu": 90, "Urziceni": 85},
    "Giurgiu": {"Bucharest": 90},
    "Urziceni": {"Bucharest": 85, "Hirsova": 98, "Vaslui": 142},
    "Hirsova": {"Urziceni": 98, "Eforie": 86},
    "Eforie": {"Hirsova": 86},
    "Vaslui": {"Urziceni": 142, "Iasi": 92},
    "Iasi": {"Vaslui": 92, "Neamt": 87},
    "Neamt": {"Iasi": 87}
}

initial = "Arad"
goal = "Neamt"
frontier = []

def goal_test(state):
    if state==goal:
        return True
    else:
        return False
    

def graphSearch(initial,goal,graph):
    frontier.append(initial)
    actions=list()
    print(actions)
    print(frontier)
    explored=set()
    while frontier:
        if len(frontier)==0: return "Fail"
        leaf=frontier.pop()
        print("current location is",leaf)
        test = goal_test(leaf)
        if test==True:
            print("Destination Reached")
            break 
        else :
            explored.add(leaf)
            actions=list(graph[leaf].keys())
            print(actions)
            for a in actions:
                if a not in explored:
                    frontier.append(a)
                    print(frontier)
            

            
            
graphSearch(initial,goal,graph)
# Out:
# []
# ['Arad']
# current location is Arad
# ['Timisoara', 'Sibiu', 'Zerind']
# ['Timisoara']
# ['Timisoara', 'Sibiu']
# ['Timisoara', 'Sibiu', 'Zerind']
# current location is Zerind
# ['Arad', 'Oradea']
# ['Timisoara', 'Sibiu', 'Oradea']
# current location is Oradea
# ['Zerind', 'Sibiu']
# ['Timisoara', 'Sibiu', 'Sibiu']
# current location is Sibiu
# ['Arad', 'Oradea', 'RimnicuVilcea', 'Fagaras']
# ['Timisoara', 'Sibiu', 'RimnicuVilcea']
# ['Timisoara', 'Sibiu', 'RimnicuVilcea', 'Fagaras']
# current location is Fagaras
# ['Sibiu', 'Bucharest']
# ['Timisoara', 'Sibiu', 'RimnicuVilcea', 'Bucharest']
# current location is Bucharest
# ['Pitesi', 'Fagaras', 'Giurgiu', 'Urziceni']
# ['Timisoara', 'Sibiu', 'RimnicuVilcea', 'Pitesi']
# ['Timisoara', 'Sibiu', 'RimnicuVilcea', 'Pitesi', 'Giurgiu']
# ['Timisoara', 'Sibiu', 'RimnicuVilcea', 'Pitesi', 'Giurgiu', 'Urziceni']
# current location is Urziceni
# ['Bucharest', 'Hirsova', 'Vaslui']
# ['Timisoara', 'Sibiu', 'RimnicuVilcea', 'Pitesi', 'Giurgiu', 'Hirsova']
# ['Timisoara', 'Sibiu', 'RimnicuVilcea', 'Pitesi', 'Giurgiu', 'Hirsova', 'Vaslui']
# current location is Vaslui
# ['Urziceni', 'Iasi']
# ['Timisoara', 'Sibiu', 'RimnicuVilcea', 'Pitesi', 'Giurgiu', 'Hirsova', 'Iasi']
# current location is Iasi
# ['Vaslui', 'Neamt']
# ['Timisoara', 'Sibiu', 'RimnicuVilcea', 'Pitesi', 'Giurgiu', 'Hirsova', 'Neamt']
# current location is Neamt
# Destination Reached
