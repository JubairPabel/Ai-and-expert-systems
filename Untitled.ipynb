# %%
c1 = [0,1,1,0,1]
c2 = [1,1,0,0,0]
c3 = [0,1,0,0,0]
c4 = [1,0,0,1,1]
x1= 0
x2= 0 
x3= 0 
x4= 0

for i in c1:
    if i == 0:
        if c1[i] == 1:
            x1 = x1+16
    if i == 1:
        if c1[i] == 1:
            x1 = x1+8
    if i == 2:
        if c1[i] == 1:
            x1 = x1+4
    if i == 3:
        if c1[i] == 1:
            x1 = x1+2
    if i == 4:
        if c1[i] == 1:
            x1 = x1+1
            
print(x1)

for i in c2:
    if i == 0:
        if c2[i] == 1:
            x2 = x2+16
    if i == 1:
        if c2[i] == 1:
            x2 = x2+8
    if i == 2:
        if c2[i] == 1:
            x2 = x2+4
    if i == 3:
        if c2[i] == 1:
            x2 = x2+2
    if i == 4:
        if c2[i] == 1:
            x2 = x2+1
            
print(x2)

for i in c3:
    if i == 0:
        if c3[i] == 1:
            x3 = x3+16
    if i == 1:
        if c3[i] == 1:
            x3 = x3+8
    if i == 2:
        if c3[i] == 1:
            x3 = x3+4
    if i == 3:
        if c3[i] == 1:
            x3 = x3+2
    if i == 4:
        if c3[i] == 1:
            x3 = x3+1
            
print(x3)

for i in c4:
    if i == 0:
        if c4[i] == 1:
            x4 = x4+16
    if i == 1:
        if c4[i] == 1:
            x4 = x4+8
    if i == 2:
        if c4[i] == 1:
            x4 = x4+4
    if i == 3:
        if c4[i] == 1:
            x4 = x4+2
    if i == 4:
        if c4[i] == 1:
            x4 = x4+1
            
print(x4)

f1 = pow(x1,2)
f2 = pow(x2,2)
f3 = pow(x3,2)
f4 = pow(x4,2)

sum= f1+f2+f3+f4

print(sum)

p1 = f1/sum
p2 = f2/sum
p3 = f3/sum
p4 = f4/sum

print(p1,p2,p3,p4)
# Out:
# 24
# 64
# 8
# 32
# 5760
# 0.1 0.7111111111111111 0.011111111111111112 0.17777777777777778
